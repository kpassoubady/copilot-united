# %%
print ("Hello World")
# Out:
# Hello World

# %%
x = 10
print (x)
# Out:
# 10

# %%
x = 10
print (x)
# Out:
# 10

# %%
import pandas as pd

# create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

print(data)
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David'], 'Age': [25, 30, 35, 40], 'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']}

# %%
df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
# print pandas version
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 2.2.3

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


# Load the dataset
def load_data(file_path):
    data = pd.read_csv(file_path)
    return data


# load airport.csv file
file_path = os.path.join(".", "data", "airports.csv") 
data = load_data(file_path)
print(data.head())
# Out:
#   iata                  name              city state country   latitude  \
# 0  00M               Thigpen       Bay Springs    MS     USA  31.953765
# 1  00M               Thigpen       Bay Springs    MS     USA  31.953765
# 2  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 3  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 4  01G          Perry-Warsaw             Perry    NY     USA  42.741347
#
#     longitude
# 0  -89.234505
# 1  -89.234505
# 2  -95.017928
# 3 -104.569893
# 4  -78.052081

# %%
# what is the correlation between 'latitude' and 'longitude' columns
correlation = data["latitude"].corr(data["longitude"])
print("Correlation between latitude and longitude:", correlation)
data.plot(x="latitude", y="longitude", kind="scatter")
plt.title("Scatter plot of latitude vs longitude")
plt.show()
# Out:
# Correlation between latitude and longitude: -0.5646609288094254

# %%
# What is correlation?
# Correlation is a statistical measure that describes the association between random variables.
